# %% [markdown]
# Посчитайте метрику Accuracy для данных в таблице.  Ответ запишите в виде десятичной дроби, при необходимости округлите ответ до двух знаков после разделителя, в качестве разделителя используйте запятую.
#
# ![Alt text](image-3.png)

# %%
TP = 11
FP = 6
FN = 10
TN = 5

# %%
Accuracy = (TP + TN)/(TP + FP + FN + TN)
Accuracy
# Out:
# 0.5
