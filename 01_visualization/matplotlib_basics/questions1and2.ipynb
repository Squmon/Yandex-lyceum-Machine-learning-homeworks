# %% [markdown]
# ### Предсказать, уволится ли сотрудник в ближайшие полгода.
# ### Посчитайте метрику MSE для данных в таблице. Ответ запишите в виде десятичной дроби, при необходимости округлите ответ до двух знаков после разделителя, в качестве разделителя используйте запятую.
#
# ![Alt text](image.png)
#
# ### Посчитайте метрику MAE для данных в таблице. Ответ запишите в виде десятичной дроби, при необходимости округлите ответ до двух знаков после разделителя, в качестве разделителя используйте запятую.
#
# ![Alt text](image-1.png)

# %% [markdown]
# 1 4 5 12 3.2 3.9

# %% [markdown]
# 1.4 3.9 5.5 11.4 2.8 4.4

# %%
import prog1
import os
