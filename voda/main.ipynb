# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
voda = pd.read_csv('./voda.csv')
print(len(voda[voda['total'] == '?']))
voda = voda[voda['total'] != '?']
voda['datetime'].is_unique
# Out:
# 118
# True

# %%
voda = voda.sort_values('datetime')

# %%
a = voda['total'].to_numpy(np.float32)
a
# Out:
# array([154140., 157818., 149311., ..., 226469., 199907., 151086.],
#       dtype=float32)

# %%
plt.plot(a[:100])
plt.show()
